# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
inp = pd.read_csv('input120.txt', sep=" ", header=None)
inp = inp.T
inp.plot()

# %%
out = pd.read_csv('output120.txt', sep=" ", header=None)
out = out.T
out.plot()
fig = out.plot(figsize=(20, 16), fontsize=26).get_figure()
fig.savefig('output120.jpg')
